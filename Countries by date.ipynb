# %%
import pandas as pd
from datetime import date
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('corona_updated.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.shape
# Out:
# (1821, 5)

# %%
df.head()
# Out:
#                 Country  TotalCases  TotalDeaths  TotalRecovered     date
# 0             Sri Lanka           1          0.0             0.0  1/29/20
# 1               Finland           1          0.0             0.0  1/29/20
# 2  United Arab Emirates           4          0.0             0.0  1/29/20
# 3                 Nepal           1          0.0             0.0  1/29/20
# 4              Cambodia           1          0.0             0.0  1/29/20

# %%
df['date'] = pd.to_datetime(df['date'])
# , format='%m%d'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 5 columns):
# Country           1821 non-null object
# TotalCases        1821 non-null int64
# TotalDeaths       1821 non-null float64
# TotalRecovered    1821 non-null float64
# date              1821 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 71.2+ KB

# %% [markdown]
# ### Number of countries by date

# %%
df.groupby(df['date'].dt.date).size().plot.bar()

# %%
num_countries = df.groupby(df['date'].dt.date).size()

# %%
# sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.figure(figsize=(12,8))
sns.countplot(x=df['date'].dt.date, data=df.reset_index())
plt.xticks(rotation=90, fontsize=13)
plt.title('Number of Countries and Regions with COVID-19 by Date', fontsize=20)
plt.ylabel('Count of Countries / Regions', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5, 0, 'Date')

# %%
df.groupby(df['date'].dt.date).size().plot()
plt.xticks(rotation=90, fontsize=13)
plt.yticks(fontsize=16)
plt.title('Number of Countries / Regions with CVOID-19 by Date', fontsize=20)
plt.ylabel('# of Countries / Regions', fontsize=16)
plt.xlabel('Date', fontsize=16)
# Out:
# Text(0.5, 0, 'Date')
