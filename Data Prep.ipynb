# %%
import pandas as pd
from datetime import date

# %%
def corona(url, date):
    corona = pd.read_html(url)
    corona_df = corona[2]
    corona_df['date'] = date
    corona_df.to_csv(f'corona_{date}.csv')
    return corona_df

# %%
today = date.today()
d1 = today.strftime("%m-%d-%Y")
print(d1)
# Out:
# 03-06-2020

# %%
# corona('https://web.archive.org/web/20200305195417/https://www.worldometers.info/coronavirus/', '03-05-2020')

# %%
df = pd.read_csv('coronavirus.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.shape
# Out:
# (1405, 5)

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#             Country  TotalCases  TotalDeaths  TotalRecovered    date
# 0             China       80430       3013.0         52259.0  3/5/20
# 1          S. Korea        6088         40.0           135.0  3/5/20
# 2             Italy        3858        148.0           414.0  3/5/20
# 3              Iran        3513        107.0           739.0  3/5/20
# 4  Diamond Princess         696          6.0           212.0  3/5/20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1405 entries, 0 to 1404
# Data columns (total 5 columns):
# Country           1405 non-null object
# TotalCases        1405 non-null int64
# TotalDeaths       1405 non-null float64
# TotalRecovered    1405 non-null float64
# date              1405 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 55.0+ KB

# %%
USA = df[df['Country'] == 'USA']

# %%
USA = USA.iloc[::-1]

# %%
USA['Percent Change'] = USA['TotalCases'].pct_change()

# %%
USA
# Out:
#      Country  TotalCases  TotalDeaths  TotalRecovered     date  Percent Change
# 1237     USA          11          0.0             0.0   2/4/20             NaN
# 1209     USA          11          0.0             0.0   2/5/20        0.000000
# 1182     USA          12          0.0             1.0   2/6/20        0.090909
# 1155     USA          12          0.0             1.0   2/7/20        0.000000
# 1127     USA          12          0.0             3.0   2/8/20        0.000000
# 1099     USA          12          0.0             3.0  2/10/20        0.000000
# 1071     USA          13          0.0             3.0  2/11/20        0.083333
# 1043     USA          13          0.0             3.0  2/12/20        0.000000
# 1014     USA          15          0.0             3.0  2/13/20        0.153846
# 985      USA          15          0.0             3.0  2/14/20        0.000000
# 956      USA          15          0.0             3.0  2/15/20        0.000000
# ...

# %%
df = df.iloc[::-1]

# %%
df.to_csv('corona_updated.csv')
